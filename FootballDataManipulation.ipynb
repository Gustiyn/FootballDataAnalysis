# %% [markdown]
# **INTERNATIONAL FOOTBALL RESULTS FROM 1872 TO 2024 DATA MANIPULATION AND PREP**  \
# https://www.kaggle.com/datasets/martj42/international-football-results-from-1872-to-2017

# %%
import os
import pandas as pd

from datetime import datetime

# %%
# Import the csv files
goalscorers = pd.read_csv('goalscorers.csv')
results = pd.read_csv('results.csv')
shootouts = pd.read_csv('shootouts.csv')

# %%
#CHECK FOR MISSING VALUES
print(goalscorers.isnull().sum())
# Out:
# date           0
# home_team      0
# away_team      0
# team           0
# scorer        49
# minute       259
# own_goal       0
# penalty        0
# dtype: int64

# %% [markdown]
# It looks like we have some missing data regarding a few goal scorers and the exact times their goals occurred

# %%
#CHECK FOR MISSING VALUES
print(results.isnull().sum())
# Out:
# date          0
# home_team     0
# away_team     0
# home_score    0
# away_score    0
# tournament    0
# city          0
# country       0
# neutral       0
# dtype: int64

# %% [markdown]
# No missing data

# %%
#CHECK FOR MISSING VALUES
print(shootouts.isnull().sum())
# Out:
# date               0
# home_team          0
# away_team          0
# winner             0
# first_shooter    415
# dtype: int64

# %% [markdown]
# We are missing some data regarding the first shooter, but that's alright, we won't be needing it.

# %%
#Drop the "first_shooter" column
shootouts = pd.DataFrame(shootouts)
shootouts.drop('first_shooter', axis=1, inplace=True)

# %%
goalscorers.head()
# Out:
#          date  home_team away_team       team            scorer  minute  \
# 0  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    44.0
# 1  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    55.0
# 2  1916-07-02      Chile   Uruguay    Uruguay  Isabelino Gradín    70.0
# 3  1916-07-02      Chile   Uruguay    Uruguay   José Piendibene    75.0
# 4  1916-07-06  Argentina     Chile  Argentina     Alberto Ohaco     2.0
#
#    own_goal  penalty
# 0     False    False
# 1     False    False
# 2     False    False
# 3     False    False
# 4     False    False

# %%
results.head()
# Out:
#          date home_team away_team  home_score  away_score tournament     city  \
# 0  1872-11-30  Scotland   England           0           0   Friendly  Glasgow
# 1  1873-03-08   England  Scotland           4           2   Friendly   London
# 2  1874-03-07  Scotland   England           2           1   Friendly  Glasgow
# 3  1875-03-06   England  Scotland           2           2   Friendly   London
# 4  1876-03-04  Scotland   England           3           0   Friendly  Glasgow
#
#     country  neutral
# 0  Scotland    False
# 1   England    False
# 2  Scotland    False
# 3   England    False
# 4  Scotland    False

# %%
shootouts.head()
# Out:
#          date    home_team         away_team       winner
# 0  1967-08-22        India            Taiwan       Taiwan
# 1  1971-11-14  South Korea  Vietnam Republic  South Korea
# 2  1972-05-07  South Korea              Iraq         Iraq
# 3  1972-05-17     Thailand       South Korea  South Korea
# 4  1972-05-19     Thailand          Cambodia     Thailand

# %%
#Goalscorers Data
#Create an unique ID for each match using the date and the first 3 letters of each country
goalscorers['date'] = pd.to_datetime(goalscorers['date'])
goalscorers['dateid'] = goalscorers['date'].dt.strftime('%Y%m%d')

goalscorers['home_country_code'] = goalscorers['home_team'].str[:3].str.upper()
goalscorers['away_country_code'] = goalscorers['away_team'].str[:3].str.upper()

goalscorers['goal_id'] = goalscorers['dateid'] + goalscorers['home_country_code'] + goalscorers['away_country_code']

# %%
#Results Data
#Create an unique ID for each match using the date and the first 3 letters of each country
results['date'] = pd.to_datetime(results['date'])
results['dateid'] = results['date'].dt.strftime('%Y%m%d')

results['home_country_code'] = results['home_team'].str[:3].str.upper()
results['away_country_code'] = results['away_team'].str[:3].str.upper()

results['match_id'] = results['dateid'] + results['home_country_code'] + results['away_country_code']

# %%
#Shootouts Data
#Create an unique ID for each match using the date and the first 3 letters of each country
shootouts['date'] = pd.to_datetime(shootouts['date'])
shootouts['dateid'] = shootouts['date'].dt.strftime('%Y%m%d')

shootouts['home_country_code'] = shootouts['home_team'].str[:3].str.upper()
shootouts['away_country_code'] = shootouts['away_team'].str[:3].str.upper()

shootouts['shootouts_id'] = shootouts['dateid'] + shootouts['home_country_code'] + shootouts['away_country_code']

# %%
# Extract France's matches Data
france_results = results[(results['home_team'] == 'France') | (results['away_team'] == 'France')]
france_goalscorers = results[(results['home_team'] == 'France') | (goalscorers['away_team'] == 'France')]
france_shootouts = shootouts[(shootouts['home_team'] == 'France') | (shootouts['away_team'] == 'France')]

# %%
france_results.head()
# Out:
#           date home_team    away_team  home_score  away_score  \
# 163 1904-05-01   Belgium       France           3           3
# 166 1905-02-12    France  Switzerland           1           0
# 177 1905-05-07   Belgium       France           7           0
# 189 1906-04-22    France      Belgium           0           5
# 206 1907-04-21   Belgium       France           1           2
#
#                tournament         city  country  neutral    dateid  \
# 163  Évence Coppée Trophy     Brussels  Belgium    False  19040501
# 166              Friendly        Paris   France    False  19050212
# 177              Friendly     Brussels  Belgium    False  19050507
# 189              Friendly  Saint-Cloud   France    False  19060422
# 206              Friendly     Brussels  Belgium    False  19070421
#
#     home_country_code away_country_code        match_id
# 163               BEL               FRA  19040501BELFRA
# 166               FRA               SWI  19050212FRASWI
# 177               BEL               FRA  19050507BELFRA
# 189               FRA               BEL  19060422FRABEL
# 206               BEL               FRA  19070421BELFRA

# %%
france_goalscorers.head()
# Out:
#           date home_team    away_team  home_score  away_score tournament  \
# 166 1905-02-12    France  Switzerland           1           0   Friendly
# 189 1906-04-22    France      Belgium           0           5   Friendly
# 223 1908-04-12    France      Belgium           1           2   Friendly
# 267 1910-04-03    France      Belgium           0           4   Friendly
# 289 1911-01-01    France      Hungary           0           3   Friendly
#
#                city country  neutral    dateid home_country_code  \
# 166           Paris  France    False  19050212               FRA
# 189     Saint-Cloud  France    False  19060422               FRA
# 223        Colombes  France    False  19080412               FRA
# 267        Gentilly  France    False  19100403               FRA
# 289  Maisons-Alfort  France    False  19110101               FRA
#
#     away_country_code        match_id
# 166               SWI  19050212FRASWI
# 189               BEL  19060422FRABEL
# 223               BEL  19080412FRABEL
# 267               BEL  19100403FRABEL
# 289               HUN  19110101FRAHUN

# %%
france_shootouts.head()
# Out:
#           date home_team       away_team          winner    dateid  \
# 53  1982-07-08   Germany          France         Germany  19820708
# 94  1986-06-21    Brazil          France          France  19860621
# 212 1996-06-22    France     Netherlands          France  19960622
# 213 1996-06-26    France  Czech Republic  Czech Republic  19960626
# 238 1998-05-29   Morocco          France         Morocco  19980529
#
#     home_country_code away_country_code    shootouts_id
# 53                GER               FRA  19820708GERFRA
# 94                BRA               FRA  19860621BRAFRA
# 212               FRA               NET  19960622FRANET
# 213               FRA               CZE  19960626FRACZE
# 238               MOR               FRA  19980529MORFRA

# %% [markdown]
# **Creates a new column called match_status in the franceMatchResultsHome DataFrame,
# based on the scores of home and away matches**

# %%
franceMatchResultsHome = france_results[(france_results.home_team == 'France')]
franceMatchResultsAway = france_results[(france_results.away_team == 'France')]

franceMatchResultsHome.loc[:, 'match_status'] = franceMatchResultsHome[['home_score', 'away_score']].apply(
    lambda row: 'draw' if row['home_score'] == row['away_score']
    else 'lose' if row['home_score'] < row['away_score']
    else 'win', axis=1
)
franceMatchResultsAway.loc[:, 'match_status'] = franceMatchResultsAway[['home_score', 'away_score']].apply(
    lambda row: 'draw' if row['home_score'] == row['away_score']
    else 'lose' if row['home_score'] > row['away_score']
    else 'win', axis=1
)
# Out:
# C:\Users\saeru\AppData\Local\Temp\ipykernel_23468\4200460198.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   franceMatchResultsHome.loc[:, 'match_status'] = franceMatchResultsHome[['home_score', 'away_score']].apply(
# C:\Users\saeru\AppData\Local\Temp\ipykernel_23468\4200460198.py:9: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   franceMatchResultsAway.loc[:, 'match_status'] = franceMatchResultsAway[['home_score', 'away_score']].apply(

# %%
#New dataframes with the match status
france_match_result = pd.concat([franceMatchResultsHome, franceMatchResultsAway], axis=0).reset_index(drop=True)
france_match_result.head()
# Out:
#         date home_team    away_team  home_score  away_score tournament  \
# 0 1905-02-12    France  Switzerland           1           0   Friendly
# 1 1906-04-22    France      Belgium           0           5   Friendly
# 2 1908-04-12    France      Belgium           1           2   Friendly
# 3 1910-04-03    France      Belgium           0           4   Friendly
# 4 1911-01-01    France      Hungary           0           3   Friendly
#
#              city country  neutral    dateid home_country_code  \
# 0           Paris  France    False  19050212               FRA
# 1     Saint-Cloud  France    False  19060422               FRA
# 2        Colombes  France    False  19080412               FRA
# 3        Gentilly  France    False  19100403               FRA
# 4  Maisons-Alfort  France    False  19110101               FRA
#
#   away_country_code        match_id match_status
# 0               SWI  19050212FRASWI          win
# 1               BEL  19060422FRABEL         lose
# 2               BEL  19080412FRABEL         lose
# 3               BEL  19100403FRABEL         lose
# 4               HUN  19110101FRAHUN         lose

# %%
#EXPERTION DES DONNEES AU FORMAT EXCEL POUR VISUALISATION AVEC TABLEAU
france_match_result.to_excel("France_Matches.xlsx", index=False)
france_goalscorers.to_excel("Goalscorers.xlsx", index=False)
france_shootouts.to_excel("Shootouts.xlsx", index=False)
